# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Load dataset

# %%
import pandas as pd

# Load dataset
data = pd.read_csv('/Users/kelly/Desktop/github-fun-projects/city-of-new-york-air-quality-measurement/data/air_quality_data.csv')

# Display the first 5 rows of the dataset
print(data.head())
# Out:
#    Unique ID  Indicator ID                                   Name  \
# 0     179772           640  Boiler Emissions- Total SO2 Emissions
# 1     179785           640  Boiler Emissions- Total SO2 Emissions
# 2     178540           365                Fine particles (PM 2.5)
# 3     178561           365                Fine particles (PM 2.5)
# 4     823217           365                Fine particles (PM 2.5)
#
#           Measure Measure Info Geo Type Name  Geo Join ID  \
# 0  Number per km2       number         UHF42        409.0
# 1  Number per km2       number         UHF42        209.0
# 2            Mean       mcg/m3         UHF42        209.0
# 3            Mean       mcg/m3         UHF42        409.0
# 4            Mean       mcg/m3         UHF42        409.0
#
#             Geo Place Name          Time Period  Start_Date  Data Value  \
# 0         Southeast Queens                 2015  01/01/2015         0.3
# 1  Bensonhurst - Bay Ridge                 2015  01/01/2015         1.2
# 2  Bensonhurst - Bay Ridge  Annual Average 2012  12/01/2011         8.6
# 3         Southeast Queens  Annual Average 2012  12/01/2011         8.0
# 4         Southeast Queens          Summer 2022  06/01/2022         6.1
#
#    Message
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %% [markdown]
# ### Examination of Basic Structure and Summary Statistics

# %%
# Display basic information about the dataset
print("info", data.info())

# Display summary statistics of the dataset
print("summary stats", data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18025 entries, 0 to 18024
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       18025 non-null  int64
#  1   Indicator ID    18025 non-null  int64
#  2   Name            18025 non-null  object
#  3   Measure         18025 non-null  object
#  4   Measure Info    18025 non-null  object
#  5   Geo Type Name   18025 non-null  object
#  6   Geo Join ID     18016 non-null  float64
#  7   Geo Place Name  18016 non-null  object
#  8   Time Period     18025 non-null  object
#  9   Start_Date      18025 non-null  object
#  10  Data Value      18025 non-null  float64
#  11  Message         0 non-null      float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 1.7+ MB
# info None
# summary stats            Unique ID  Indicator ID   Geo Join ID    Data Value  Message
# count   18025.000000  18025.000000  1.801600e+04  18025.000000      0.0
# mean   426387.692705    434.830180  5.906303e+05     21.428616      NaN
# std    250489.450630    115.852371  7.769549e+06     23.999345      NaN
# min    121644.000000    365.000000  1.000000e+00      0.000000      NaN
# 25%    175303.000000    365.000000  2.020000e+02      8.900000      NaN
# 50%    410803.000000    375.000000  3.030000e+02     15.200000      NaN
# 75%    649893.000000    386.000000  4.040000e+02     26.700000      NaN
# max    828353.000000    661.000000  1.051061e+08    424.700000      NaN

# %% [markdown]
# ### Check for Missing Values

# %%
# Check for missing values
print(data.isnull().sum())

# Visualize missing values
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()
# Out:
# Unique ID             0
# Indicator ID          0
# Name                  0
# Measure               0
# Measure Info          0
# Geo Type Name         0
# Geo Join ID           9
# Geo Place Name        9
# Time Period           0
# Start_Date            0
# Data Value            0
# Message           18025
# dtype: int64

# %% [markdown]
# #### Drop Unnecesary Cloumns

# %%
data = data.drop(columns=['Message'])

# %% [markdown]
# #### Handle missing values

# %%
data = data.dropna(subset=['Geo Join ID', 'Geo Place Name'])

# %% [markdown]
# ### Examination of Geo Locations

# %%
df = pd.DataFrame(data)

# Get unique values in the 'Measure Info' column
geo_unique_values = df['Geo Place Name'].unique()

# Print the unique values
print(geo_unique_values)
# Out:
# ['Southeast Queens' 'Bensonhurst - Bay Ridge' 'Rockaways'
#  'Coney Island - Sheepshead Bay' 'Williamsburg - Bushwick'
#  'Bayside - Little Neck' 'Pelham - Throgs Neck' 'Upper West Side'
#  'East New York' 'Canarsie - Flatlands' 'Jamaica'
#  'Gramercy Park - Murray Hill' 'Hunts Point - Mott Haven'
#  'Southwest Queens' 'Greenwich Village - SoHo' 'Brooklyn'
#  'Downtown - Heights - Slope' 'Washington Heights' 'Northeast Bronx'
#  'Greenpoint' 'Long Island City - Astoria' 'Port Richmond'
#  'Kingsbridge - Riverdale' 'Throgs Neck and Co-op City (CD10)'
#  'Williamsbridge and Baychester (CD12)' 'Jamaica and Hollis (CD12)'
#  'South Ozone Park and Howard Beach (CD10)'
#  'Kingsbridge Heights and Bedford (CD7)' 'Sunset Park (CD7)'
#  'Rockaway and Broad Channel (CD14)' 'Upper West Side (CD7)'
#  'Flushing and Whitestone (CD7)' 'Bushwick (CD4)'
#  'Bedford Stuyvesant (CD3)' 'Jackson Heights (CD3)'
#  'East Flatbush - Flatbush' 'Elmhurst and Corona (CD4)'
#  'Highbridge and Concourse (CD4)' 'Lower East Side and Chinatown (CD3)'
#  'Morrisania and Crotona (CD3)' 'Upper East Side (CD8)'
#  'Central Harlem (CD10)' 'Washington Heights and Inwood (CD12)'
#  'Union Square - Lower East Side' 'Manhattan'
#  'Bedford Stuyvesant - Crown Heights' 'High Bridge - Morrisania'
#  'Woodside and Sunnyside (CD2)' 'Hunts Point and Longwood (CD2)'
#  'Greenwich Village and Soho (CD2)' 'Upper East Side' 'Crotona -Tremont'
#  'Flushing - Clearview' 'East Harlem' 'Fordham - Bronx Pk'
#  'Chelsea - Clinton' 'Central Harlem - Morningside Heights'
#  'Fresh Meadows' 'Bay Ridge and Dyker Heights (CD10)'
#  'Fort Greene and Brooklyn Heights (CD2)'
#  'Greenpoint and Williamsburg (CD1)' 'Mott Haven and Melrose (CD1)'
#  'Lower Manhattan' 'West Queens' 'Parkchester and Soundview (CD9)'
#  'Kew Gardens and Woodhaven (CD9)' 'Morris Park and Bronxdale (CD11)'
#  'Bayside and Little Neck (CD11)'
#  'Morningside Heights and Hamilton Heights (CD9)' 'East Harlem (CD11)'
#  'South Crown Heights and Lefferts Gardens (CD9)'
#  'East New York and Starrett City (CD5)' 'Midtown (CD5)' 'Queens'
#  'Queens Village (CD13)' 'Park Slope and Carroll Gardens (CD6)'
#  'Stuyvesant Town and Turtle Bay (CD6)'
#  'Hillcrest and Fresh Meadows (CD8)' 'Bronx'
#  'Long Island City and Astoria (CD1)'
#  'Fordham and University Heights (CD5)' 'Riverdale and Fieldston (CD8)'
#  'Clinton and Chelsea (CD4)' 'Crown Heights and Prospect Heights (CD8)'
#  'Rego Park and Forest Hills (CD6)' 'Bensonhurst (CD11)' 'Sunset Park'
#  'Brownsville (CD16)' 'St. George and Stapleton (CD1)'
#  'Financial District (CD1)' 'Borough Park' 'Coney Island (CD13)'
#  'Sheepshead Bay (CD15)' 'Staten Island' 'Ridgewood - Forest Hills'
#  'Belmont and East Tremont (CD6)' 'Flatbush and Midwood (CD14)'
#  'Borough Park (CD12)' 'East Flatbush (CD17)'
#  'Ridgewood and Maspeth (CD5)' 'Willowbrook' 'Northern SI'
#  'Stapleton - St. George' 'Southern SI' 'Flatlands and Canarsie (CD18)'
#  'South Beach and Willowbrook (CD2)' 'Bayside Little Neck-Fresh Meadows'
#  'South Beach - Tottenville' 'South Bronx'
#  'Tottenville and Great Kills (CD3)' 'Upper East Side-Gramercy'
#  'Chelsea-Village' 'Union Square-Lower Manhattan' 'New York City']

# %%
# show full response of geo place name counts
pd.set_option('display.max_rows', None) 
print(df['Geo Place Name'].value_counts())
# Out:
# Geo Place Name
# Southeast Queens                                  269
# Downtown - Heights - Slope                        269
# Bedford Stuyvesant - Crown Heights                269
# East Flatbush - Flatbush                          269
# Flushing - Clearview                              269
# East Harlem                                       269
# Fordham - Bronx Pk                                269
# Central Harlem - Morningside Heights              269
# Bensonhurst - Bay Ridge                           269
# West Queens                                       269
# Sunset Park                                       269
# Kingsbridge - Riverdale                           269
# Borough Park                                      269
# Greenpoint                                        269
# Northeast Bronx                                   269
# Washington Heights                                269
# Long Island City - Astoria                        269
# East New York                                     269
# Pelham - Throgs Neck                              269
# Southwest Queens                                  269
# Rockaways                                         269
# Jamaica                                           269
# Coney Island - Sheepshead Bay                     269
# Canarsie - Flatlands                              269
# Williamsburg - Bushwick                           269
# Ridgewood - Forest Hills                          269
# Upper West Side                                   269
# High Bridge - Morrisania                          170
# Upper East Side                                   170
# Crotona -Tremont                                  170
# South Beach - Tottenville                         170
# Staten Island                                     170
# Chelsea - Clinton                                 170
# Lower Manhattan                                   170
# Queens                                            170
# Bronx                                             170
# Stapleton - St. George                            170
# Willowbrook                                       170
# Union Square - Lower East Side                    170
# Manhattan                                         170
# Fresh Meadows                                     170
# New York City                                     170
# Port Richmond                                     170
# Bayside - Little Neck                             170
# Gramercy Park - Murray Hill                       170
# Hunts Point - Mott Haven                          170
# Brooklyn                                          170
# Greenwich Village - SoHo                          170
# Clinton and Chelsea (CD4)                         110
# Bensonhurst (CD11)                                110
# Rego Park and Forest Hills (CD6)                  110
# Crown Heights and Prospect Heights (CD8)          110
# Fordham and University Heights (CD5)              110
# Riverdale and Fieldston (CD8)                     110
# Brownsville (CD16)                                110
# Long Island City and Astoria (CD1)                110
# Williamsbridge and Baychester (CD12)              110
# Washington Heights and Inwood (CD12)              110
# Stuyvesant Town and Turtle Bay (CD6)              110
# Throgs Neck and Co-op City (CD10)                 110
# Coney Island (CD13)                               110
# St. George and Stapleton (CD1)                    110
# Financial District (CD1)                          110
# Queens Village (CD13)                             110
# Sheepshead Bay (CD15)                             110
# Belmont and East Tremont (CD6)                    110
# Flatbush and Midwood (CD14)                       110
# Borough Park (CD12)                               110
# East Flatbush (CD17)                              110
# Ridgewood and Maspeth (CD5)                       110
# Flatlands and Canarsie (CD18)                     110
# South Beach and Willowbrook (CD2)                 110
# Tottenville and Great Kills (CD3)                 110
# Park Slope and Carroll Gardens (CD6)              110
# Central Harlem (CD10)                             110
# Jamaica and Hollis (CD12)                         110
# Sunset Park (CD7)                                 110
# Upper East Side (CD8)                             110
# Morrisania and Crotona (CD3)                      110
# Lower East Side and Chinatown (CD3)               110
# Highbridge and Concourse (CD4)                    110
# Woodside and Sunnyside (CD2)                      110
# Hunts Point and Longwood (CD2)                    110
# Greenwich Village and Soho (CD2)                  110
# Elmhurst and Corona (CD4)                         110
# Jackson Heights (CD3)                             110
# Bedford Stuyvesant (CD3)                          110
# Bushwick (CD4)                                    110
# Midtown (CD5)                                     110
# Upper West Side (CD7)                             110
# Rockaway and Broad Channel (CD14)                 110
# Flushing and Whitestone (CD7)                     110
# Bay Ridge and Dyker Heights (CD10)                110
# Morris Park and Bronxdale (CD11)                  110
# East New York and Starrett City (CD5)             110
# South Crown Heights and Lefferts Gardens (CD9)    110
# East Harlem (CD11)                                110
# Morningside Heights and Hamilton Heights (CD9)    110
# Fort Greene and Brooklyn Heights (CD2)            110
# Bayside and Little Neck (CD11)                    110
# Hillcrest and Fresh Meadows (CD8)                 110
# Kew Gardens and Woodhaven (CD9)                   110
# Parkchester and Soundview (CD9)                   110
# South Ozone Park and Howard Beach (CD10)          110
# Kingsbridge Heights and Bedford (CD7)             110
# Mott Haven and Melrose (CD1)                      110
# Greenpoint and Williamsburg (CD1)                 110
# Northern SI                                        99
# Bayside Little Neck-Fresh Meadows                  99
# South Bronx                                        99
# Upper East Side-Gramercy                           99
# Chelsea-Village                                    99
# Union Square-Lower Manhattan                       99
# Southern SI                                        99
# Name: count, dtype: int64

# %%
# print how many unique locations
unique_locations = data['Geo Place Name'].nunique()
print(unique_locations)
# Out:
# 114

# %% [markdown]
# ### Examination of Time Period Values

# %%
# Check unique values and their counts in the 'Time Period' column
time_period_counts = data['Time Period'].value_counts()
print(time_period_counts)

# Check for unique values and potential issues
unique_time_periods = data['Time Period'].unique()
print(unique_time_periods)
# Out:
# Time Period
# 2017-2019                          480
# 2005-2007                          480
# 2012-2014                          480
# 2015-2017                          480
# 2009-2011                          480
# Summer 2014                        423
# Summer 2018                        423
# Summer 2020                        423
# Summer 2017                        423
# Summer 2019                        423
# Summer 2010                        423
# Summer 2015                        423
# Summer 2022                        423
# Summer 2012                        423
# Summer 2009                        423
# Summer 2011                        423
# Summer 2013                        423
# Summer 2016                        423
# Summer 2021                        423
# 2005                               417
# 2010                               321
# 2019                               321
# Winter 2017-18                     282
# Winter 2008-09                     282
# Annual Average 2022                282
# Annual Average 2016                282
# Winter 2013-14                     282
# Annual Average 2013                282
# Winter 2009-10                     282
# Winter 2011-12                     282
# Annual Average 2014                282
# Winter 2016-17                     282
# Annual Average 2019                282
# Annual Average 2017                282
# Winter 2018-19                     282
# Annual Average 2020                282
# Winter 2021-22                     282
# Annual Average 2010                282
# Annual Average 2012                282
# Winter 2012-13                     282
# Winter 2020-21                     282
# Annual Average 2011                282
# Annual Average 2015                282
# Annual Average 2009                282
# Annual Average 2018                282
# Winter 2015-16                     282
# Winter 2014-15                     282
# Annual Average 2021                282
# Winter 2010-11                     282
# Winter 2019-20                     282
# 2011                               214
# 2013                               144
# 2015                               144
# 2-Year Summer Average 2009-2010    141
# 2014                                96
# Name: count, dtype: int64
# ['2015' 'Annual Average 2012' 'Summer 2022' 'Summer 2012' 'Summer 2013'
#  'Summer 2021' 'Annual Average 2013' 'Annual Average 2017' 'Summer 2009'
#  '2013' 'Summer 2016' 'Summer 2011' 'Annual Average 2016' 'Winter 2021-22'
#  'Winter 2010-11' 'Annual Average 2021' 'Winter 2014-15' 'Winter 2015-16'
#  'Annual Average 2018' 'Summer 2014' 'Annual Average 2009'
#  'Annual Average 2015' 'Annual Average 2011' 'Summer 2010'
#  'Winter 2020-21' 'Winter 2019-20' 'Winter 2012-13' 'Summer 2015'
#  '2009-2011' '2015-2017' 'Annual Average 2010' 'Summer 2019'
#  'Annual Average 2020' 'Winter 2018-19' '2012-2014' 'Annual Average 2019'
#  'Winter 2017-18' 'Winter 2008-09' 'Annual Average 2022' '2005-2007'
#  'Winter 2013-14' '2010' 'Summer 2017' 'Winter 2009-10' 'Winter 2011-12'
#  'Summer 2020' 'Summer 2018' 'Annual Average 2014' 'Winter 2016-17'
#  '2017-2019' '2005' '2019' '2-Year Summer Average 2009-2010' '2014' '2011']

# %%
# Get unique values in the 'Measure Info' column
unique_values = df['Measure Info'].value_counts()

# Print the unique values
print(unique_values)
# Out:
# Measure Info
# ppb                     8037
# mcg/m3                  5922
# per 100,000 adults      1440
# per square mile          963
# per 100,000 children     720
# Âµg/m3                   406
# number                   288
# per 100,000              240
# Name: count, dtype: int64
